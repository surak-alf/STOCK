# %%
import pandas as pd
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import sys
import os

# Get the directory of the current notebook
current_dir = os.path.dirname(os.path.abspath('../scripts')) 

# Add the 'scripts' directory to the Python path
scripts_dir = os.path.join(current_dir, 'scripts')
sys.path.append(scripts_dir)

from EDA import download_stock_data
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 11
#       8 scripts_dir = os.path.join(current_dir, 'scripts')
#       9 sys.path.append(scripts_dir)
# ---> 11 from EDA import download_stock_data
#
# ModuleNotFoundError: No module named 'EDA'

# %%
from EDA import download_stock_data
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from EDA import download_stock_data
#
# ModuleNotFoundError: No module named 'EDA'

# %%
tm_long_data = download_stock_data("TM", "max", "1d")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
tm_long_data.head()
# Out:
# Price          Close      High       Low      Open Volume
# Ticker            TM        TM        TM        TM     TM
# Date
# 1980-03-17  2.296797  2.334143  2.296797  0.000000  41109
# 1980-03-18  2.306135  2.343481  2.306135  0.000000   9343
# 1980-03-19  2.306135  2.306135  2.306135  2.306135      0
# 1980-03-20  2.306135  2.343481  2.306135  0.000000  10277
# 1980-03-21  2.362154  2.399500  2.362154  0.000000   8409

# %%
tm_long_data.shape
# Out:
# (11298, 5)

# %%
tm_long_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 11298 entries, 1980-03-17 to 2025-01-08
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   (Close, TM)   11298 non-null  float64
#  1   (High, TM)    11298 non-null  float64
#  2   (Low, TM)     11298 non-null  float64
#  3   (Open, TM)    11298 non-null  float64
#  4   (Volume, TM)  11298 non-null  int64
# dtypes: float64(4), int64(1)
# memory usage: 529.6 KB

# %%
tm_long_data.describe()
# Out:
# Price          Close          High           Low          Open        Volume
# Ticker            TM            TM            TM            TM            TM
# count   11298.000000  11298.000000  11298.000000  11298.000000  1.129800e+04
# mean       63.666785     64.034084     63.301607     60.808400  2.148655e+05
# std        52.355995     52.621957     52.045363     55.282919  3.873993e+05
# min         2.259451      2.259451      2.259451      0.000000  0.000000e+00
# 25%        19.224642     19.355423     19.224642      0.000000  1.350000e+04
# 50%        50.617449     51.031762     50.292166     50.728913  9.139050e+04
# 75%       104.819155    105.336487    104.201612    104.899049  2.926000e+05
# max       254.770004    255.229996    253.589996    255.000000  1.858270e+07

# %%
# Identify numerical columns
numerical_columns = tm_long_data.select_dtypes(include=[np.number]).columns

# Perform univariate analysis on numerical columns
for column in numerical_columns:
    # For continuous variables
    if len(tm_long_data[column].unique()) > 10:  
        plt.figure(figsize=(8, 6))
        sns.histplot(tm_long_data[column], kde=True)
        plt.title(f'Histogram of {column}')
        plt.xlabel(column)
        plt.ylabel('Frequency')
        plt.show()

# %%
tm_long_data
# Out:
# Price            Close        High         Low        Open  Volume
# Ticker              TM          TM          TM          TM      TM
# Date
# 1980-03-17    2.296798    2.334144    2.296798    0.000000   41109
# 1980-03-18    2.306134    2.343480    2.306134    0.000000    9343
# 1980-03-19    2.306134    2.306134    2.306134    2.306134       0
# 1980-03-20    2.306134    2.343480    2.306134    0.000000   10277
# 1980-03-21    2.362153    2.399499    2.362153    0.000000    8409
# ...                ...         ...         ...         ...     ...
# 2025-01-02  193.119995  194.800003  192.000000  194.399994  615500
# 2025-01-03  195.250000  195.500000  193.229996  194.190002  611300
# 2025-01-06  190.389999  193.270004  189.839996  193.000000  664400
# 2025-01-07  193.119995  194.970001  192.419998  194.589996  585500
# 2025-01-08  192.550003  193.020004  191.520004  192.960007  436500
#
# [11298 rows x 5 columns]

# %%
correlation_matrix = tm_long_data.corr()

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
tm_long_data

# %%
tm_long_data=tm_long_data.reset_index()

# %%
tm_long_data
# Out:
# Price        Date       Close        High         Low        Open  Volume
# Ticker                     TM          TM          TM          TM      TM
# 0      1980-03-17    2.296798    2.334144    2.296798    0.000000   41109
# 1      1980-03-18    2.306134    2.343480    2.306134    0.000000    9343
# 2      1980-03-19    2.306134    2.306134    2.306134    2.306134       0
# 3      1980-03-20    2.306134    2.343480    2.306134    0.000000   10277
# 4      1980-03-21    2.362153    2.399499    2.362153    0.000000    8409
# ...           ...         ...         ...         ...         ...     ...
# 11293  2025-01-02  193.119995  194.800003  192.000000  194.399994  615500
# 11294  2025-01-03  195.250000  195.500000  193.229996  194.190002  611300
# 11295  2025-01-06  190.389999  193.270004  189.839996  193.000000  664400
# 11296  2025-01-07  193.119995  194.970001  192.419998  194.589996  585500
# 11297  2025-01-08  192.550003  193.020004  191.520004  192.960007  436500
#
# ...

# %%
tm_long_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11298 entries, 0 to 11297
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   (Date, )      11298 non-null  datetime64[ns]
#  1   (Close, TM)   11298 non-null  float64
#  2   (High, TM)    11298 non-null  float64
#  3   (Low, TM)     11298 non-null  float64
#  4   (Open, TM)    11298 non-null  float64
#  5   (Volume, TM)  11298 non-null  int64
# dtypes: datetime64[ns](1), float64(4), int64(1)
# memory usage: 529.7 KB

# %%
plt.figure(figsize=(12, 6))
plt.plot(tm_long_data.index, tm_long_data['Close'])
plt.title(f'Close Price for TM')
plt.xlabel('Date')
plt.ylabel('Close Price TM')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(tm_long_data.index, tm_long_data['Open'])
plt.title(f'Open Price for TM')
plt.xlabel('Date')
plt.ylabel('Open Price TM')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(tm_long_data.index, tm_long_data['High'])
plt.title(f'High Price for TM')
plt.xlabel('Date')
plt.ylabel('High Price TM')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(tm_long_data.index, tm_long_data['Low'])
plt.title(f'Low Price for TM')
plt.xlabel('Date')
plt.ylabel('Low Price TM')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(tm_long_data.index, tm_long_data['Volume'])
plt.title(f'Volume Price for TM')
plt.xlabel('Date')
plt.ylabel('Volume Price TM')
plt.grid(True)
plt.show()
